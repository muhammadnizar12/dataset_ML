# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadnizar12/dataset_ML/blob/main/muhammadnizar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print('Python: {}'.format(sys.version))
import scipy
print('scipy: {}'.format(scipy.__version__))
import numpy
print('numpy: {}'.format(numpy.__version__))
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
import pandas
print('pandas: {}'.format(pandas.__version__))
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# scipy: 1.11.3
# numpy: 1.23.5
# matplotlib: 3.7.1
# pandas: 1.5.3
# sklearn: 1.2.2

# %%
import pandas as pd
path="/content/data_penembakan.csv"
dataset=pd.read_csv(path, sep=";")
dataset
# Out:
#                     name        date   manner_of_death         armed gender  \
# 0             Tim Elliot  02/01/2015              shot           gun      M
# 1       Lewis Lee Lembke  02/01/2015              shot           gun      M
# 2     John Paul Quintero  03/01/2015  shot and Tasered       unarmed      M
# 3        Matthew Hoffman  04/01/2015              shot    toy weapon      M
# 4      Michael Rodriguez  04/01/2015              shot      nail gun      M
# ...                  ...         ...               ...           ...    ...
# 4941      William Slyter  13/06/2020              shot           gun      M
# 4942               TK TK  13/06/2020              shot  undetermined      M
# 4943      Nicholas Hirsh  15/06/2020              shot           gun      M
# 4944               TK TK  16/06/2020              shot           gun      M
# 4945               TK TK  16/06/2020              shot           gun      M
#
# ...

# %%
dataset.head()
# Out:
#                  name        date   manner_of_death       armed gender  \
# 0          Tim Elliot  02/01/2015              shot         gun      M
# 1    Lewis Lee Lembke  02/01/2015              shot         gun      M
# 2  John Paul Quintero  03/01/2015  shot and Tasered     unarmed      M
# 3     Matthew Hoffman  04/01/2015              shot  toy weapon      M
# 4   Michael Rodriguez  04/01/2015              shot    nail gun      M
#
#             city state  signs_of_mental_illness threat_level         flee  \
# 0        Shelton    WA                     True       attack  Not fleeing
# 1          Aloha    OR                    False       attack  Not fleeing
# 2        Wichita    KS                    False        other  Not fleeing
# 3  San Francisco    CA                     True       attack  Not fleeing
# 4          Evans    CO                    False       attack  Not fleeing
#
#    body_camera
# 0        False
# 1        False
# 2        False
# 3        False
# ...

# %%
dataset.shape
# Out:
# (4946, 11)
